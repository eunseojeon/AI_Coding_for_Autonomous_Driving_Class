# %% [markdown]
# <a href="https://colab.research.google.com/github/eunseojeon/AI_Coding_for_Autonomous_Driving_Class/blob/main/0716_YOLOv8(2)%EB%8F%99%EC%98%81%EC%83%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1️⃣ 필요 패키지 설치

# %%
# !pip install ultralytics

# %% [markdown]
# ## 2️⃣ 라이브러리 임포트 및 모델 로드

# %%
from ultralytics import YOLO
from google.colab import files

# COCO 사전 훈련된 YOLOv8n 모델 로드
model = YOLO("yolov8n.pt")
model.info()  # 모델 정보 확인
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 75.6MB/s]
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %% [markdown]
# ## 3️⃣ 동영상 파일 업로드

# %%
# 동영상 파일 업로드
uploaded = files.upload()
video_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-f7f933a0-7389-4f8b-b878-66695673d704" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7f933a0-7389-4f8b-b878-66695673d704">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 4️⃣ 동영상 추론 및 결과 저장

# %%
# 동영상 파일에 대해 YOLOv8n 모델로 추론 실행 및 결과 저장
results = model.predict(video_path, save=True)  # save=True로 결과 파일 저장

# 결과 영상 파일 이름 확인
import glob
import os

# 결과 파일은 'runs/detect/predict' 디렉터리에 저장됩니다.
result_dir = "runs/detect/predict"
output_files = glob.glob(os.path.join(result_dir, "*.mp4"))

# Colab에서 결과 영상 다운로드
from google.colab import files
for file in output_files:
    files.download(file)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/245) /content/저작권없는 영상소스 #도로영상 #주행.mp4: 384x640 3 cars, 321.7ms
# video 1/1 (frame 2/245) /content/저작권없는 영상소스 #도로영상 #주행.mp4: 384x640 3 cars, 296.3ms
# video 1/1 (frame 3/245) /content/저작권없는 영상소스 #도로영상 #주행.mp4: 384x640 3 cars, 280.2ms
# video 1/1 (frame 4/245) /content/저작권없는 영상소스 #도로영상 #주행.mp4: 384x640 4 cars, 247.4ms
# ...

# %% [markdown]
# 5. 이미지와 동영상의 주요 변경점 및 참고
# - model(image_path) → model.predict(video_path, save=True) 이미지를 사용하는 대신 동영상 파일을 사용합니다.
# - 결과 영상은 runs/detect/predict 폴더에 저장되며, 객체가 탐지된 장면이 포함됩니다.
# - 필요에 따라 conf, device 등의 파라미터를 추가해 추론 설정을 변경할 수 있습니다.
# 6. 추가 팁
# - 다양한 영상 포맷(.mp4, .avi 등)을 사용할 수 있습니다.
# - 높은 해상도의 경우 추론 시간이 오래 걸릴 수 있으니 에포크 수나 이미지 크기 등을 조정하세요.
# - Colab 환경에 따라 결과 파일의 경로가 달라질 수 있으니, 출력 경로를 항상 확인하세요.
