# %% [markdown]
# <a href="https://colab.research.google.com/github/eunseojeon/AI_Coding_for_Autonomous_Driving_Class/blob/main/0724_%EA%B0%9D%EC%B2%B4%EC%9D%B8%EC%8B%9D(%EC%A0%84%EC%9D%B4%ED%95%99%EC%8A%B5)_%EC%B5%9C%EC%A2%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 전이학습 후 best.pt 파일을 얻도록 roboflow의 프로젝트를 가져옴
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Qf6hiXfH3aEEfDQSdc4q")
project = rf.workspace("jeoneunseo").project("traffic_detection_2-84vds")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 62.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic_detection_2-1 in yolov8:: 100%|██████████| 1014/1014 [00:00<00:00, 7038.89it/s]

# %%
#### 2. Ultralytics YOLOv8 설치 (처음 한 번만)
# !pip install ultralytics

#### 3. YOLOv8 전이학습용 코드 작성
from ultralytics import YOLO

# coco-pretrained YOLOv8n 모델 로드
model = YOLO("yolov8n.pt")  # 다른 사이즈: yolov8s.pt, yolov8m.pt 등

# 학습 시작
model.train(
    data="/content/traffic_detection_2-1/data.yaml",  # 첫 실행때 생기는 data.yaml 파일 내부를 수정해주고,
    epochs=50,
    imgsz=640,
    batch=16,
    name="traffic-custom",
    pretrained=True
)

#### 4. `best.pt` 파일 경로 확인 및 다운로드
from google.colab import files
files.download('runs/detect/traffic-custom/weights/best.pt')  # 두번째 실행때 생기는 폴더에서 best.pt를 다운받음.

### :pushpin: 참고사항
print(dataset.location)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# GPU사용을 다 써서 CPU로 했더니 Epoch가 너무 느려서 9번 정도 하고 멈춤.

# %%
# !pip install yt-dlp  # 유튜브 영상을 다운받기위한 yt-dlp 설치

from ultralytics import YOLO
import yt_dlp
import tempfile  # 유튜브 링크로 다운받고 빠른 처리를 위한 설정을 하는 용도

youtube_url = input("🎥 유튜브 영상 주소를 입력하세요: ").strip()  # https://youtu.be/WVb-cQUID2A?si=NFcGFduRuvOYWfQ8 사용할 예정

# yt-dlp 다운로드 옵션
temp_dir = tempfile.gettempdir()
ydl_opts = {
        'format': 'mp4/best[height<=480]',  # 480p로 제한 (빠른 처리)
        'outtmpl': tempfile.gettempdir() + '/temp_video.%(ext)s',
        'quiet': True,
    }

# 유튜브 링크로 영상 가져오기
try:
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        print("⬇️ 유튜브 영상 다운로드 중...")
        info = ydl.extract_info(youtube_url, download=True)
        video_path = ydl.prepare_filename(info)
        print(f"✅ 다운로드 완료: {video_path}")
except Exception as e:
    raise RuntimeError(f"❌ 다운로드 실패: {e}")

# 🔍 내가 위에서 전이학습을 한 YOLOv8 모델 로드 및 추론
print("🔎 YOLOv8 객체 탐지 실행 중...")
model = YOLO("/content/runs/detect/traffic-custom/weights/best.pt")

import os
from google.colab import files

# 🎯 추론 수행 (결과 저장)
results = model.predict(
    source=video_path,
    save=True,
    name="video-result",  # runs/detect/video-result/ 하위에 결과 저장
    conf=0.25
)

# 📦 결과 비디오 경로 추정
output_path = "runs/detect/video-result/temp_video.avi"

# 📥 결과 영상 다운로드
if os.path.exists(output_path):
    print(f"📁 결과 영상 다운로드 중: {output_path}")
    files.download(output_path)
else:
    print("⚠️ 결과 영상 파일을 찾을 수 없습니다. 경로를 다시 확인하세요.")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# video 1/1 (frame 7210/98386) /tmp/temp_video.mp4: 384x640 1 traffic_sign, 187.0ms
# video 1/1 (frame 7211/98386) /tmp/temp_video.mp4: 384x640 1 traffic_sign, 163.2ms
# video 1/1 (frame 7212/98386) /tmp/temp_video.mp4: 384x640 2 traffic_signs, 162.5ms
# video 1/1 (frame 7213/98386) /tmp/temp_video.mp4: 384x640 1 traffic_sign, 167.5ms
# video 1/1 (frame 7214/98386) /tmp/temp_video.mp4: 384x640 2 traffic_signs, 166.2ms
# video 1/1 (frame 7215/98386) /tmp/temp_video.mp4: 384x640 2 traffic_signs, 194.9ms
# video 1/1 (frame 7216/98386) /tmp/temp_video.mp4: 384x640 2 traffic_signs, 165.8ms
# video 1/1 (frame 7217/98386) /tmp/temp_video.mp4: 384x640 1 lane, 1 traffic_sign, 169.2ms
# video 1/1 (frame 7218/98386) /tmp/temp_video.mp4: 384x640 (no detections), 176.8ms
# video 1/1 (frame 7219/98386) /tmp/temp_video.mp4: 384x640 (no detections), 163.0ms
# video 1/1 (frame 7220/98386) /tmp/temp_video.mp4: 384x640 1 lane, 171.8ms
# ...

# %% [markdown]
# 98000장을 다 하기엔 너무 많아서 중간에 멈춤.
