# %% [markdown]
# <a href="https://colab.research.google.com/github/eunseojeon/AI-Coding-for-Autonomous-Driving/blob/main/0627_%ED%8C%8C%EC%9D%B4%EC%8D%AC_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📦✨tuple 이해하기
# - 튜플은 관련된 데이터 값들을 하나로 묶어놓은 **"데이터 묶음"**
# - **튜플은 "택배 상자"**라고 생각: 상자 안에 여러 물건들이 들어있음 (물건1, 물건2, 물건3). 언패킹은 상자를 열어서 물건들을 꺼내는 것. 꺼낸 물건들을 각각 다른 장소에 정리하는 것
#
# #### 택배상자 (튜플)
# - package = ('책', '펜', '노트')
#
# #### 상자 열어서 물건들 꺼내기 (언패킹)
# - book, pen, notebook = package

# %% [markdown]
# ❗️ 리스트와 튜플의 차이점

# %% [markdown]
# ![스크린샷 2025-06-27 10.53.54.png](data:image/png;base64,...)

# %% [markdown]
# ❗️ 리스트처럼 인덱스를 사용해서 튜플의 요소에 접근 가능

# %%
colors = ("빨강", "파랑", "초록", "노랑")

# 인덱스로 접근하기
print(colors[0]) # 출력: 빨강
print(colors[2]) # 출력: 초록
print(colors[-1]) # 출력: 노랑 (마지막)

# 슬라이싱도 가능해요!
print(colors[1:3]) # 출력: ('파랑', '초록')
# Out:
# 빨강
# 초록
# 노랑
# ('파랑', '초록')

# %% [markdown]
# ✅ 튜플 생성

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# ✅ 튜플은 중복값을 허용한다

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %% [markdown]
# ✅ 튜플 길이 확인

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %% [markdown]
# ✅ 하나의 항목으로 튜플 만들기
# - 항목이 하나만 있는 튜플을 만들려면 항목 뒤에 쉼표를 추가해야함.

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# ✅ 튜플에는 모든 데이터 유형이 될 수 있음

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)

print("과일 목록:", tuple1)
print("숫자 목록:", tuple2)
print("불리언 값들:", tuple3)

print("첫 번째 과일은:", tuple1[0])
print("가장 큰 숫자는:", max(tuple2))
print("True의 개수는:", tuple3.count(True))
# Out:
# 과일 목록: ('apple', 'banana', 'cherry')
# 숫자 목록: (1, 5, 7, 9, 3)
# 불리언 값들: (True, False, False)
# 첫 번째 과일은: apple
# 가장 큰 숫자는: 9
# True의 개수는: 1

# %%
tuple1 = ("abc", 34, True, 40, "male")

print("튜플 전체:", tuple1)
print("이름:", tuple1[0])
print("나이:", tuple1[1])
print("활성 여부:", tuple1[2])
print("점수:", tuple1[3])
print("성별:", tuple1[4])
# Out:
# 튜플 전체: ('abc', 34, True, 40, 'male')
# 이름: abc
# 나이: 34
# 활성 여부: True
# 점수: 40
# 성별: male

# %% [markdown]
# ✅ tuple()생성자를 사용하여 튜플을 만드는 것도 가능

# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# ✅ 튜플의 두 번째 항목을 출력

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %% [markdown]
# ✅ 음수 인덱싱
# - 음수 인덱싱을 끝에서부터 시작한다는 것을 의미
# - -1은 마지막 항목, -2는 두번째로 마지막 항목을 의미

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %% [markdown]
# ✅ 인덱스 범위
# -  범위의 시작점과 끝점을 지정하여 인덱스 범위 지정 가능
# - 범위를 지정하면 반환값은 지정된 항목이 포함된 새 튜플이 됨

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5]) #세번째~다섯번째 항목 출력 (2포함에서 시작하여 5포함하지 않음에서 끝남)
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:4]) #kiwi의 앞 항목들을 반환
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:]) #cherry부터 마지막까지의 항목들을 반환
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %% [markdown]
# ## 🚗 실제 자율주행에서의 활용

# %% [markdown]
# 🛞 PART 1: Tuple Unpacking 기본 - 자율주행 예제

# %%
# 1. 기본 좌표 언패킹

vehicle_position = (127.5, 37.5)  # 경도, 위도

longitude, latitude = vehicle_position
print(f"차량 위치: 경도 {longitude}, 위도 {latitude}")
# Out:
# 차량 위치: 경도 127.5, 위도 37.5

# %% [markdown]
# 🛞 "PART 2: Tuple Unpacking + 리스트 조합"

# %%
# 여러 센서 데이터를 리스트로 관리

sensor_readings = [
    (8.5, 45, 'lidar'),      # 거리, 각도, 센서타입
    (12.3, 0, 'camera'),     # 거리, 각도, 센서타입
    (15.7, -30, 'radar'),    # 거리, 각도, 센서타입
    (2.1, 90, 'ultrasonic')  # 거리, 각도, 센서타입
]

print("센서별 감지 정보:")
for sensor_data in sensor_readings:
    dist, ang, sensor_type = sensor_data  # tuple unpacking
    print(f"{sensor_type}: {dist}m, {ang}도")


# 위험 센서 찾기 (5m 이내)
print("\n위험 감지 센서:")
for sensor_data in sensor_readings:
    dist, ang, sensor_type = sensor_data
    if dist < 5.0:
        print(f"⚠️ {sensor_type}: {dist}m (위험)")
# 경로 포인트들을 리스트로 관리
waypoints = [
    (0, 0, '출발지'),
    (5, 3, '경유지1'),
    (10, 8, '경유지2'),
    (15, 12, '목적지')
]

print("\n경로 계획:")
for point in waypoints:
    x, y, name = point
    print(f"{name}: ({x}, {y})")
# 교차로 정보들
intersections = [
    ('서울역', 'green', 25),
    ('시청', 'red', 40),
    ('종로3가', 'yellow', 5),
    ('을지로', 'green', 15)
]

print("\n교차로 신호등 현황:")
for intersection in intersections:
    name, signal_color, remaining_time = intersection
    print(f"{name}: {signal_color} ({remaining_time}초)")

print("\n" + "="*50)
# Out:
# 센서별 감지 정보:
# lidar: 8.5m, 45도
# camera: 12.3m, 0도
# radar: 15.7m, -30도
# ultrasonic: 2.1m, 90도
#
# 위험 감지 센서:
# ⚠️ ultrasonic: 2.1m (위험)
#
# 경로 계획:
# 출발지: (0, 0)
# 경유지1: (5, 3)
# 경유지2: (10, 8)
# 목적지: (15, 12)
#
# 교차로 신호등 현황:
# 서울역: green (25초)
# 시청: red (40초)
# 종로3가: yellow (5초)
# 을지로: green (15초)
#
# ...

# %% [markdown]
# - 튜플: ('서울역앞', 'red', 25, 12) - 교차로 정보
# - 리스트: intersections - 여러 교차로 데이터
# - 딕셔너리: intersection_details - 상세 정보 매핑
# - 셋: processed_intersections - 처리된 교차로 추적
# - for문: 교차로 데이터 순회
# - if문: 긴급상황 판단
# ---

# %% [markdown]
# 🛞 PART 3: Tuple Unpacking + 딕셔너리 조합

# %%
print("=== PART 3: Tuple Unpacking + 딕셔너리 조합 ===")

# 차량별 위치 정보를 딕셔너리로 관리
vehicle_locations = {
    'car_001': (127.1, 37.5, 60),    # 경도, 위도, 속도
    'car_002': (127.2, 37.6, 45),
    'car_003': (127.3, 37.4, 80),
    'truck_001': (127.0, 37.3, 70)
}

print("차량별 현재 위치:")
for vehicle_id, location_data in vehicle_locations.items():
    lon, lat, spd = location_data  # tuple unpacking
    print(f"{vehicle_id}: ({lon}, {lat}), {spd}km/h")

# 충전소 정보를 딕셔너리로 관리
charging_stations = {
    '강남충전소': (127.027, 37.498, 5, 2),    # 경도, 위도, 총슬롯, 사용중슬롯
    '서초충전소': (127.032, 37.483, 8, 6),
    '송파충전소': (127.105, 37.514, 6, 1)
}

print("\n충전소 현황:")
for station_name, station_info in charging_stations.items():
    lon, lat, total_slots, used_slots = station_info
    available = total_slots - used_slots
    print(f"{station_name}: 위치({lon}, {lat}), 사용가능 {available}/{total_slots}슬롯")

# 주차장 구역별 정보
parking_areas = {
    'A구역': (50, 45, 'compact'),     # 총자리, 사용중, 차량크기
    'B구역': (30, 30, 'standard'),
    'C구역': (20, 15, 'large'),
    'D구역': (15, 8, 'handicapped')
}

print("\n주차장 현황:")
for area_name, area_info in parking_areas.items():
    total, occupied, car_type = area_info
    available = total - occupied
    utilization = round((occupied / total) * 100, 1)
    print(f"{area_name} ({car_type}): {available}/{total}자리 사용가능 (사용률 {utilization}%)")

print("\n" + "="*50)
# Out:
# === PART 3: Tuple Unpacking + 딕셔너리 조합 ===
# 차량별 현재 위치:
# car_001: (127.1, 37.5), 60km/h
# car_002: (127.2, 37.6), 45km/h
# car_003: (127.3, 37.4), 80km/h
# truck_001: (127.0, 37.3), 70km/h
#
# 충전소 현황:
# 강남충전소: 위치(127.027, 37.498), 사용가능 3/5슬롯
# 서초충전소: 위치(127.032, 37.483), 사용가능 2/8슬롯
# 송파충전소: 위치(127.105, 37.514), 사용가능 5/6슬롯
#
# 주차장 현황:
# A구역 (compact): 5/50자리 사용가능 (사용률 90.0%)
# B구역 (standard): 0/30자리 사용가능 (사용률 100.0%)
# C구역 (large): 5/20자리 사용가능 (사용률 75.0%)
# D구역 (handicapped): 7/15자리 사용가능 (사용률 53.3%)
#
# ...

# %% [markdown]
# - 튜플: ('EV001', 25, (127.1, 37.5), 'sedan') - 차량 정보
# - 리스트: electric_vehicles - 차량 목록
# - 딕셔너리: charging_stations - 충전소 정보
# - 셋: urgent_vehicles - 긴급 충전 차량
# - for문: 차량별, 충전소별 순회
# - if문: 배터리 잔량에 따른 판단

# %% [markdown]
# 🛞 PART 4: 실전 응용 - 종합 교통 관제 시스템

# %%
print("=== PART 4: 실전 응용 - 종합 교통 관제 시스템 ===")

# 실시간 교통 데이터 (시간, 위치(경도, 위도), 속도, 차량타입, 차선)
traffic_data = [
    ('09:15', (127.1, 37.5), 45, 'sedan', 1),   # sedan → 세단
    ('09:16', (127.2, 37.6), 60, 'truck', 2),    # truck → 트럭
    ('09:17', (127.3, 37.4), 30, 'bus', 1),      # bus → 버스
    ('09:18', (127.0, 37.3), 80, 'sedan', 3)     # sedan → 세단
]

print("실시간 교통 모니터링:")  # 실시간 교통 상황 출력
for data in traffic_data:
    time, position, speed, vehicle_type, lane = data  # 튜플 값 언패킹 (시간, 위치, 속도, 차량유형, 차선)
    lon, lat = position  # 위치 정보도 따로 나눔 (경도, 위도)
    print(f"{time} | {vehicle_type} | ({lon}, {lat}) | {speed}km/h | {lane}차선")
    # 예: 09:15 | sedan | (127.1, 37.5) | 45km/h | 1차선

# 사고 신고 데이터 (시간, 위치, 심각도, 처리 여부)
accident_reports = [
    ('10:30', (127.15, 37.55), 'minor', False),  # minor → 경미한 사고, False → 아직 처리 안 됨
    ('10:45', (127.25, 37.65), 'major', True),   # major → 큰 사고, True → 처리 완료
    ('11:00', (127.35, 37.45), 'minor', False)   # 처리 안 된 경미한 사고
]

print("\n사고 신고 현황:")  # 줄바꿈 후 사고 정보 출력
for report in accident_reports:
    time, location, severity, handled = report  # 데이터 언패킹
    lon, lat = location
    status = "처리완료" if handled else "처리중"  # handled: True → 완료, False → 진행 중
    print(f"{time} | ({lon}, {lat}) | {severity} | {status}")
    # 예: 10:45 | (127.25, 37.65) | major | 처리완료

# 처리되지 않은 사고만 출력
print("\n미처리 사고:")
for report in accident_reports:
    time, location, severity, handled = report
    if not handled:  # 처리 안 된 경우만
        lon, lat = location
        print(f"⚠️ {time} | ({lon}, {lat}) | {severity} - 즉시 처리 필요")
        # ⚠️ 경고 표시 포함

# 날씨별 권장 주행 조건 (날씨, 최대속도, 안전거리 배수, 라이트 사용 여부)
weather_conditions = [
    ('맑음', 100, 1.0, False),  # False → 라이트 사용 안 해도 됨
    ('비', 80, 1.5, True),     # True → 라이트 켜야 함
    ('눈', 60, 2.0, True),
    ('안개', 50, 2.5, True)
]

current_weather = '비'  # 현재 날씨 설정 ('맑음', '비', '눈', '안개' 중 하나)

print(f"\n현재 날씨: {current_weather}")
print("권장 주행 조건:")
for condition in weather_conditions:
    weather, max_speed, distance_factor, lights_on = condition
    if weather == current_weather:
        print(f"최대속도: {max_speed}km/h")  # max_speed → speed limit in km/h
        print(f"안전거리: 평소의 {distance_factor}배")  # distance_factor → following distance multiplier
        print(f"라이트 사용: {'필수' if lights_on else '선택'}")  # lights_on → whether headlights are required
        break  # 현재 날씨 조건 찾았으면 종료

# 차량 상태 진단 (차량ID, 엔진 상태 점수, 브레이크 상태 점수, 종합 판정)
vehicle_diagnostics = {
    'EV001': (95, 88, 'excellent'),    # excellent → 매우 양호
    'EV002': (82, 75, 'good'),         # good → 양호
    'EV003': (65, 45, 'caution'),      # caution → 주의 필요
    'EV004': (45, 30, 'maintenance')   # maintenance → 정비 필요
}

print("\n차량 상태 진단:")
for vehicle_id, diagnosis in vehicle_diagnostics.items():
    engine_score, brake_score, overall_status = diagnosis
    avg_score = (engine_score + brake_score) / 2  # 평균 점수 계산
    print(f"{vehicle_id}: 엔진 {engine_score}점, 브레이크 {brake_score}점, 평균 {avg_score:.1f}점 ({overall_status})")
    # overall_status는 'excellent', 'good', 'caution', 'maintenance'

# 정비가 필요한 차량만 따로 출력
print("\n정비 필요 차량:")
for vehicle_id, diagnosis in vehicle_diagnostics.items():
    engine_score, brake_score, overall_status = diagnosis
    if overall_status in ['caution', 'maintenance']:  # 주의 또는 정비 필요 상태만 걸러냄
        print(f"🔧 {vehicle_id}: {overall_status} - 점검 필요")
# Out:
# === PART 4: 실전 응용 - 종합 교통 관제 시스템 ===
# 실시간 교통 모니터링:
# 09:15 | sedan | (127.1, 37.5) | 45km/h | 1차선
# 09:16 | truck | (127.2, 37.6) | 60km/h | 2차선
# 09:17 | bus | (127.3, 37.4) | 30km/h | 1차선
# 09:18 | sedan | (127.0, 37.3) | 80km/h | 3차선
#
# 사고 신고 현황:
# 10:30 | (127.15, 37.55) | minor | 처리중
# 10:45 | (127.25, 37.65) | major | 처리완료
# 11:00 | (127.35, 37.45) | minor | 처리중
#
# 미처리 사고:
# ⚠️ 10:30 | (127.15, 37.55) | minor - 즉시 처리 필요
# ⚠️ 11:00 | (127.35, 37.45) | minor - 즉시 처리 필요
#
# 현재 날씨: 비
# 권장 주행 조건:
# 최대속도: 80km/h
# 안전거리: 평소의 1.5배
# 라이트 사용: 필수
#
# 차량 상태 진단:
# EV001: 엔진 95점, 브레이크 88점, 평균 91.5점 (excellent)
# EV002: 엔진 82점, 브레이크 75점, 평균 78.5점 (good)
# EV003: 엔진 65점, 브레이크 45점, 평균 55.0점 (caution)
# EV004: 엔진 45점, 브레이크 30점, 평균 37.5점 (maintenance)
#
# 정비 필요 차량:
# 🔧 EV003: caution - 점검 필요
# 🔧 EV004: maintenance - 점검 필요

# %% [markdown]
# (위 코드 주석으로 설명 완료)
